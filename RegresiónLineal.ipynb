# %%
import matplotlib.pyplot as plt
from sklearn import linear_model #usando sklearn para saber los valores optimos.
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("G:/octavo semestre/Análisis de datos/Unidad 1/Etapa 2/Dataset/Regresión Lineal/data.csv",sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.plot.scatter(x="metro", y="precio")
plt.show()

# %%
#Parametros de la recta
w=11.2
b=285 #b=319

# %%
# puntos de la recta
x = np.linspace(0,data['metro'].max(),100)
y = w*x+b

# grafica de la recta
data.plot.scatter(x='metro',y='precio')
plt.plot(x, y, '-r')
plt.ylim(0,data['precio'].max()*1.1)
# plt.grid()
plt.show()
